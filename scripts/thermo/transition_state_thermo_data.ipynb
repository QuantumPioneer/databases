# %%
import pathlib

from functools import lru_cache

import pandas as pd
import swifter

from rdkit import Chem

# %%
cwd = pathlib.Path().absolute()
QUANTUM_GREEN_DIR = pathlib.Path("/home/shared/projects/quantum_green")
PAPER_DIR = QUANTUM_GREEN_DIR / "paper" / "figure" / "section_3_1_2_ts_char"
DATABASE_DIR = cwd.parent.parent / "data" / "thermo"

# %%
pd.set_option("display.max_columns", None)


def head(df, n=2):
    display(df.head(n))
    print(f"Contains {len(df)} rows")


@lru_cache(maxsize=None)
def canonical_smiles(smiles):
    mol = Chem.MolFromSmiles(smiles)
    for atom in mol.GetAtoms():
        atom.SetAtomMapNum(0)
    return Chem.MolToSmiles(mol, isomericSmiles=True)


def clean_rxn_smi(rxn_smi):
    return ">>".join(
        [
            ".".join([canonical_smiles(smi) for smi in category.split(".")])
            for category in rxn_smi.split(">>")
        ]
    )


def get_rxn_smi(row):
    return row["r1smi"] + "." + row["r2smi"] + ">>" + row["p1smi"] + "." + row["p2smi"]

# %%
thermo_data = pd.read_pickle(
    PAPER_DIR / "quantum_green_ts_data_24july2c.pkl"
)
thermo_data["rxn_smi"] = thermo_data.swifter.apply(get_rxn_smi, axis=1)
head(thermo_data)
# Out:
#                       ts_dft_log_source_utf_8_sha512  dft_table_id  \
# 0  4c648a435eb66f655a9afa7aebe1b6288cfbe5d4377ab7...        545983
# 1  3fcdf61497a20d2e765655162f9a50bd8067a6ae90e90e...        545984
#
#                                      ts_dft_log_path  \
# 0  /home/gridsan/groups/RMG/Projects/Habs/data/ts...
# 1  /home/gridsan/groups/RMG/Projects/Habs/data/ts...
#
#                                 ts_dft_route_section  charge  multiplicity  \
# 0  P opt=(ts,calcall,maxcycle=64,noeig,nomicro,ca...       0             2
# 1  P opt=(ts,calcall,maxcycle=64,noeig,nomicro,ca...       0             2
#
#    ts_dft_opt_max_steps  ts_dft_opt_normal_termination_check  \
# 0                    64                                 True
# 1                    64                                 True
#
#    ts_dft_opt_cpu_time  ts_dft_opt_wall_time  \
# 0              53637.5                1178.8
# 1              87382.4                1915.1
#
# ...

# %%
thermo_data["clean_rxn_smi"] = thermo_data["rxn_smi"].swifter.apply(clean_rxn_smi)
# Out:
# Pandas Apply:   0%|          | 0/167237 [00:00<?, ?it/s]

# %%
thermo_df = pd.DataFrame(
    {
        "rxn_smi": thermo_data["clean_rxn_smi"],
        "dlpno_sp_hartree": thermo_data["ts_dlpno_sp_hartree"],
        "dft_zpe_scaled_hartree": 0.9723865877712031
        * thermo_data["ts_dft_zpe_hartree"],
    }
)
head(thermo_df)
# Out:
#                                     rxn_smi  dlpno_sp_hartree  \
# 0    [O]O.CC(CC=O)C1CC1>>C[C](CC=O)C1CC1.OO       -499.420713
# 1  [O]O.COCC(C)OC1CC1>>[CH2]OCC(C)OC1CC1.OO       -575.755980
#
#    dft_zpe_scaled_hartree
# 0                0.182474
# 1                0.210423
# Contains 167237 rows

# %%
delta = thermo_df["dft_zpe_scaled_hartree"] - thermo_data["ts_dft_zpe_scaled_hartree"]
delta.min(), delta.max()
# Out:
# (np.float64(0.0), np.float64(0.0))

# %% [markdown]
# Looking for duplicates

# %%
thermo_df[thermo_df["rxn_smi"].duplicated(keep=False)].sort_values(by="rxn_smi")
# Out:
#                                               rxn_smi  dlpno_sp_hartree  \
# 24695   [O]O.CCCc1nc(C)c[nH]1>>C[CH]Cc1nc(C)c[nH]1.OO       -533.687075
# 60097   [O]O.CCCc1nc(C)c[nH]1>>C[CH]Cc1nc(C)c[nH]1.OO       -533.686479
# 1827         [O]O.Cc1[nH]cnc1C=O>>Cc1[nH]cnc1[C]=O.OO       -529.132458
# 29769        [O]O.Cc1[nH]cnc1C=O>>Cc1[nH]cnc1[C]=O.OO       -529.132837
# 27394    [O]O.Cc1cc(C=O)n[nH]1>>Cc1cc([C]=O)n[nH]1.OO       -529.109163
# 53602    [O]O.Cc1cc(C=O)n[nH]1>>Cc1cc([C]=O)n[nH]1.OO       -529.107864
# 118423  [O]O.c1cc(C2CC2)n[nH]1>>C1=CC(C2CC2)=N[N]1.OO       -493.155124
# 121220  [O]O.c1cc(C2CC2)n[nH]1>>C1=CC(C2CC2)=N[N]1.OO       -493.154929
#
#         dft_zpe_scaled_hartree
# 24695                 0.190482
# 60097                 0.190482
# 1827                  0.119058
# 29769                 0.119058
# 27394                 0.118688
# 53602                 0.118127
# 118423                0.140986
# 121220                0.140986

# %%
thermo_df_no_duplicates = thermo_df.drop_duplicates(subset="rxn_smi", keep=False)

# %%
thermo_df_no_duplicates.to_csv(
    DATABASE_DIR / "quantumpioneer_thermo_dataset_transition_states.csv", index=False
)
